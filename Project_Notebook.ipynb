# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data= pd.read_csv("T_ONTIME_MARKETING 3.csv")

# %%
jan_data= data[data['ARR_DELAY'].notnull()]

# %%
data2= pd.read_csv("T_ONTIME_MARKETING 2.csv")
feb_data= data2[data2['ARR_DELAY'].notnull()]

# %%
data3= pd.read_csv("T_ONTIME_MARKETING 4.csv")
mar_data= data3[data3['ARR_DELAY'].notnull()]

# %%
data4= pd.read_csv("T_ONTIME_MARKETING 5.csv")
apr_data= data4[data4['ARR_DELAY'].notnull()]

# %%
data5= pd.read_csv("T_ONTIME_MARKETING 6.csv")
may_data= data5[data5['ARR_DELAY'].notnull()]

# %%
data6= pd.read_csv("T_ONTIME_MARKETING 7.csv")
june_data= data6[data6['ARR_DELAY'].notnull()]

# %%
data7= pd.read_csv("T_ONTIME_MARKETING 8.csv")
july_data= data7[data7['ARR_DELAY'].notnull()]

# %%
data8= pd.read_csv("T_ONTIME_MARKETING 9.csv")
aug_data= data8[data8['ARR_DELAY'].notnull()]

# %%
data9= pd.read_csv("T_ONTIME_MARKETING 10.csv")
sep_data= data9[data9['ARR_DELAY'].notnull()]

# %%
data10= pd.read_csv("T_ONTIME_MARKETING 11.csv")
oct_data= data10[data10['ARR_DELAY'].notnull()]

# %%
data11= pd.read_csv("T_ONTIME_MARKETING 12.csv")
nov_data= data11[data11['ARR_DELAY'].notnull()]

# %%
data12= pd.read_csv("T_ONTIME_MARKETING 13.csv")
dec_data= data12[data12['ARR_DELAY'].notnull()]

# %%
data.columns
# Out:
# Index(['QUARTER', 'MONTH', 'FL_DATE', 'MKT_CARRIER', 'MKT_CARRIER_FL_NUM',
#        'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'DEST',
#        'DEST_CITY_NAME', 'DEST_STATE_ABR', 'CRS_DEP_TIME', 'DEP_TIME',
#        'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15', 'DEP_DELAY_GROUP',
#        'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15',
#        'ARR_DELAY_GROUP', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME',
#        'AIR_TIME', 'DISTANCE', 'DISTANCE_GROUP'],
#       dtype='object')

# %%
print(list(set(jan_data['MKT_CARRIER'])))
print(list(set(feb_data['MKT_CARRIER'])))
print(list(set(mar_data['MKT_CARRIER'])))
print(list(set(apr_data['MKT_CARRIER'])))
print(list(set(may_data['MKT_CARRIER'])))
print(list(set(june_data['MKT_CARRIER'])))
print(list(set(july_data['MKT_CARRIER'])))
print(list(set(aug_data['MKT_CARRIER'])))
print(list(set(sep_data['MKT_CARRIER'])))
print(list(set(oct_data['MKT_CARRIER'])))
print(list(set(nov_data['MKT_CARRIER'])))
print(list(set(dec_data['MKT_CARRIER'])))
# Out:
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']
# ['AS', 'AA', 'G4', 'HA', 'F9', 'UA', 'DL', 'NK', 'WN', 'B6']

# %%
delays= [np.mean(jan_data['ARR_DELAY_NEW']),
         np.mean(feb_data['ARR_DELAY_NEW']),
         np.mean(mar_data['ARR_DELAY_NEW']),
         np.mean(apr_data['ARR_DELAY_NEW']),
         np.mean(may_data['ARR_DELAY_NEW']),
         np.mean(june_data['ARR_DELAY_NEW']),
         np.mean(july_data['ARR_DELAY_NEW']),
         np.mean(aug_data['ARR_DELAY_NEW']),
         np.mean(sep_data['ARR_DELAY_NEW']),
         np.mean(oct_data['ARR_DELAY_NEW']),
         np.mean(nov_data['ARR_DELAY_NEW']),
         np.mean(dec_data['ARR_DELAY_NEW'])]

print(delays)
x_pos= range(len(delays))
x_axis= ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.bar(x_pos, delays)
plt.ylabel('Average Arrival Delay (minutes)')
plt.xlabel('Month')
plt.title('Average Delay Time Across Domestic Routes in 2022')
plt.xticks(x_pos, x_axis);
# Out:
# [14.354921483258492, 14.22176289364896, 15.282290116612899, 15.949220248947393, 15.079478974372895, 17.849852879505566, 17.326682130740213, 16.505686887456314, 11.354517213692414, 10.860706299899226, 13.114833843170238, 20.889188976248107]

# %%
AS=[np.mean(jan_data[jan_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='AS']['ARR_DELAY_NEW'])]

# %%
UA=[np.mean(jan_data[jan_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='UA']['ARR_DELAY_NEW'])]

# %%
B6=[np.mean(jan_data[jan_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='B6']['ARR_DELAY_NEW'])]

# %%
G4=[np.mean(jan_data[jan_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='G4']['ARR_DELAY_NEW'])]

# %%
AA=[np.mean(jan_data[jan_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='AA']['ARR_DELAY_NEW'])]

# %%
WN=[np.mean(jan_data[jan_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='WN']['ARR_DELAY_NEW'])]

# %%
F9=[np.mean(jan_data[jan_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='F9']['ARR_DELAY_NEW'])]

# %%
NK=[np.mean(jan_data[jan_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='NK']['ARR_DELAY_NEW'])]

# %%
DL=[np.mean(jan_data[jan_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='DL']['ARR_DELAY_NEW'])]

# %%
HA=[np.mean(jan_data[jan_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(feb_data[feb_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(mar_data[mar_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(apr_data[apr_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(may_data[may_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(june_data[june_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(july_data[july_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(aug_data[aug_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(sep_data[sep_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(oct_data[oct_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(nov_data[nov_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW']),
np.mean(dec_data[dec_data['MKT_CARRIER']=='HA']['ARR_DELAY_NEW'])]

# %%
fig = plt.figure(figsize=(10,6))
x_pos= range(len(UA))
x_axis= ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'July', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.plot(AS, label= 'Alaska Airlines', marker='o')
plt.plot(UA, label= 'United Airlines', marker='o')
plt.plot(B6, label= 'JetBlue', marker='o')
plt.plot(G4, label= 'Allegiant Air', marker='o')
plt.plot(AA, label= 'American Airlines', marker='o')
plt.plot(WN, label= 'Southwest Airlines', marker='o')
plt.plot(F9, label= 'Frontier Airlines', marker='o')
plt.plot(NK, label= 'Spirit Airlines', marker='o')
plt.plot(DL, label= 'Delta Airlines', marker='o')
plt.plot(HA, label= 'Hawaiian Airlines', marker='o')
plt.xlabel('Month')
plt.ylabel('Average Arrival Delay Time (minutes)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(x_pos, x_axis)
plt.title('On Time Performance for Domestic Travel in 2022');

# %%
print(np.mean(AS))
print(np.mean(UA))
print(np.mean(B6))
print(np.mean(G4))
print(np.mean(AA))
print(np.mean(WN))
print(np.mean(F9))
print(np.mean(NK))
print(np.mean(DL))
print(np.mean(HA))
# Out:
# 11.284306116672937
# 15.16245320409012
# 26.330550716570357
# 23.98602593727829
# 16.211003951800407
# 13.62608825887518
# 24.127856682261978
# 17.71493173620887
# 12.640437048587351
# 12.461412680678142

# %%
airlines= ['', 'AS', 'UA', 'B6', 'G4', 'AA', 'WN', 'F9', 'NK', 'DL', 'HA']
plt.boxplot([AS, UA, B6, G4, AA, WN, F9, NK, DL, HA])
plt.title('Distribution of Average Arrival Delay for each Airline')
plt.xlabel('Airline')
plt.ylabel('Average Arrival Delay (minutes)')
plt.xticks(range(11), airlines);

# %%
# scatter plot to show relationship between departure delay and arrival delay, both in minutes, for every month in 2022

fig, ax = plt.subplots(2,6)
plt.figure(figsize=(10,6))
ax[0,0].scatter(jan_data['DEP_DELAY_NEW'],jan_data['ARR_DELAY_NEW'])
ax[0,0].plot(jan_data['DEP_DELAY_NEW'], jan_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[0,1].scatter(feb_data['DEP_DELAY_NEW'],feb_data['ARR_DELAY_NEW'])
ax[0,1].plot(feb_data['DEP_DELAY_NEW'], feb_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[0,2].scatter(mar_data['DEP_DELAY_NEW'],mar_data['ARR_DELAY_NEW'])
ax[0,2].plot(mar_data['DEP_DELAY_NEW'], mar_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[0,3].scatter(apr_data['DEP_DELAY_NEW'],apr_data['ARR_DELAY_NEW'])
ax[0,3].plot(apr_data['DEP_DELAY_NEW'], apr_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[0,4].scatter(may_data['DEP_DELAY_NEW'],may_data['ARR_DELAY_NEW'])
ax[0,4].plot(may_data['DEP_DELAY_NEW'], may_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[0,5].scatter(june_data['DEP_DELAY_NEW'],june_data['ARR_DELAY_NEW'])
ax[0,5].plot(june_data['DEP_DELAY_NEW'], june_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[1,0].scatter(july_data['DEP_DELAY_NEW'],july_data['ARR_DELAY_NEW'])
ax[1,0].plot(july_data['DEP_DELAY_NEW'], july_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[1,1].scatter(aug_data['DEP_DELAY_NEW'],aug_data['ARR_DELAY_NEW'])
ax[1,1].plot(aug_data['DEP_DELAY_NEW'], aug_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[1,2].scatter(sep_data['DEP_DELAY_NEW'],sep_data['ARR_DELAY_NEW'])
ax[1,2].plot(sep_data['DEP_DELAY_NEW'], sep_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[1,3].scatter(oct_data['DEP_DELAY_NEW'],oct_data['ARR_DELAY_NEW'])
ax[1,3].plot(oct_data['DEP_DELAY_NEW'], oct_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[1,4].scatter(nov_data['DEP_DELAY_NEW'],nov_data['ARR_DELAY_NEW'])
ax[1,4].plot(nov_data['DEP_DELAY_NEW'], nov_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')
ax[1,5].scatter(dec_data['DEP_DELAY_NEW'],dec_data['ARR_DELAY_NEW'])
ax[1,5].plot(dec_data['DEP_DELAY_NEW'], dec_data['DEP_DELAY_NEW'], color = 'red', label = 'x=y')

for ax in ax.flat:  # Hide x labels and tick labels for top plots and y ticks for right plots.
    ax.label_outer()

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import tree

# create dictionary mapping airline codes to numbers
airline_dict = {'AA': 1, 'AS': 2, 'B6': 3, 'DL': 4, 'F9': 5, 'G4': 6, 'HA': 7, 'NK': 8, 'UA': 9, 'WN': 10}

# replace airline codes with corresponding numbers
dec_data['MKT_UNIQUE_CARRIER'] = dec_data['MKT_CARRIER'].replace(airline_dict)

# select predictors and target variable
X = dec_data[['MKT_UNIQUE_CARRIER', 'DISTANCE', 'DEP_DELAY_NEW']]
y = dec_data['ARR_DELAY_NEW']

# split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state= 42)

# create and fit decision tree model
tree_model = DecisionTreeRegressor(max_depth= 5)
tree_model.fit(X_train, y_train)


# predict ARR_DELAY_NEW for specific input values
input_data = [[1, 500, 15]]
predicted_delay = tree_model.predict(input_data)

print("Predicted ARR_DELAY_NEW:", predicted_delay)
# Out:
# /var/folders/b6/nznm09hd6gz5rb04z7z7lcpw0000gn/T/ipykernel_3671/2156468387.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dec_data['MKT_UNIQUE_CARRIER'] = dec_data['MKT_CARRIER'].replace(airline_dict)
# Predicted ARR_DELAY_NEW: [12.75152088]
# /Users/harnadartut/Desktop/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
print(tree.export_text(tree_model))
# Out:
# |--- feature_2 <= 158.50
# |   |--- feature_2 <= 50.50
# |   |   |--- feature_2 <= 19.50
# |   |   |   |--- feature_2 <= 7.50
# |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |--- value: [2.12]
# |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |--- value: [4.95]
# |   |   |   |--- feature_2 >  7.50
# |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |--- value: [8.25]
# |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |--- value: [12.75]
# |   |   |--- feature_2 >  19.50
# |   |   |   |--- feature_2 <= 34.50
# |   |   |   |   |--- feature_2 <= 26.50
# |   |   |   |   |   |--- value: [18.90]
# |   |   |   |   |--- feature_2 >  26.50
# |   |   |   |   |   |--- value: [25.94]
# |   |   |   |--- feature_2 >  34.50
# |   |   |   |   |--- feature_2 <= 42.50
# |   |   |   |   |   |--- value: [34.10]
# |   |   |   |   |--- feature_2 >  42.50
# |   |   |   |   |   |--- value: [42.13]
# |   |--- feature_2 >  50.50
# ...

# %%
fig, ax = plt.subplots(2,6)
plt.figure(figsize=(10,6))
ax[0,0].scatter(jan_data['DISTANCE'],jan_data['ARR_DELAY_NEW'])
ax[0,1].scatter(feb_data['DISTANCE'],feb_data['ARR_DELAY_NEW'])
ax[0,2].scatter(mar_data['DISTANCE'],mar_data['ARR_DELAY_NEW'])
ax[0,3].scatter(apr_data['DISTANCE'],apr_data['ARR_DELAY_NEW'])
ax[0,4].scatter(may_data['DISTANCE'],may_data['ARR_DELAY_NEW'])
ax[0,5].scatter(june_data['DISTANCE'],june_data['ARR_DELAY_NEW'])
ax[1,0].scatter(july_data['DISTANCE'],july_data['ARR_DELAY_NEW'])
ax[1,1].scatter(aug_data['DISTANCE'],aug_data['ARR_DELAY_NEW'])
ax[1,2].scatter(sep_data['DISTANCE'],sep_data['ARR_DELAY_NEW'])
ax[1,3].scatter(oct_data['DISTANCE'],oct_data['ARR_DELAY_NEW'])
ax[1,4].scatter(nov_data['DISTANCE'],nov_data['ARR_DELAY_NEW'])
ax[1,5].scatter(dec_data['DISTANCE'],dec_data['ARR_DELAY_NEW'])

for ax in ax.flat:  # Hide x labels and tick labels for top plots and y ticks for right plots.
    ax.label_outer()
